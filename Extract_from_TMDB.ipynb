# %% [markdown]
# # API CALLS and Save results

# %%
# Install tmdbsimple (only need to run once)
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (2.9.1)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from tmdbsimple) (2.29.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.10/site-packages (from requests->tmdbsimple) (2.0.4)

# %%
# Import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json, time
from tqdm.notebook import tqdm_notebook

# %%
#Load TMDB API Key & Add to tmdbsimple
with open('/Users/kellyji/.secret/tmdb_api.json','r') as f:
    login=json.load(f)

login.keys()
# Out:
# dict_keys(['api-key', 'API Read Access Token'])

# %%
# Import tmdbsimple and setting the API keys
import tmdbsimple as tmdb
tmdb.API_KEY = login['api-key']

# %%
FOLDER='Data/'
os.listdir(FOLDER)
# Out:
# ['rating.csv',
#  'basics.csv',
#  'movieERD.png',
#  'title.basics.tsv.gz',
#  'title.ratings.tsv.gz',
#  'moviesqlscript.mwb',
#  'title-akas-us-only.csv',
#  'moviesqlscript.sql',
#  '.ipynb_checkpoints']

# %%
# Define customized functions
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies(movie_id)
    
    movie_info = movie.info()
    releases = movie.releases()
    
    for c in releases['countries']:
        if c['iso_3166_1' ] =='US':
            movie_info['certification'] = c['certification']
    return movie_info


def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        file_data = json.load(file)
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        file.seek(0)
        json.dump(file_data, file)

# %%
# Load in the cleaned Title Basics
basics=pd.read_csv('Data/basics.csv')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# Check API function
get_movie_with_rating('tt0848228')
# Out:
# {'adult': False,
#  'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#  'belongs_to_collection': {'id': 86311,
#   'name': 'The Avengers Collection',
#   'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#   'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#  'budget': 220000000,
#  'genres': [{'id': 878, 'name': 'Science Fiction'},
#   {'id': 28, 'name': 'Action'},
#   {'id': 12, 'name': 'Adventure'}],
#  'homepage': 'https://www.marvel.com/movies/the-avengers',
#  'id': 24428,
#  'imdb_id': 'tt0848228',
#  'original_language': 'en',
#  'original_title': 'The Avengers',
#  'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#  'popularity': 153.756,
#  'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#  'production_companies': [{'id': 420,
#    'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#    'name': 'Marvel Studios',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2012-04-25',
#  'revenue': 1518815515,
#  'runtime': 143,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#   {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#  'status': 'Released',
#  'tagline': 'Some assembly required.',
#  'title': 'The Avengers',
#  'video': False,
#  'vote_average': 7.711,
#  'vote_count': 29409,
#  'certification': 'PG-13'}

# %%
get_movie_with_rating('tt0332280')
# Out:
# {'adult': False,
#  'backdrop_path': '/qom1SZSENdmHFNZBXbtJAU0WTlC.jpg',
#  'belongs_to_collection': None,
#  'budget': 29000000,
#  'genres': [{'id': 10749, 'name': 'Romance'}, {'id': 18, 'name': 'Drama'}],
#  'homepage': 'http://www.newline.com/properties/notebookthe.html',
#  'id': 11036,
#  'imdb_id': 'tt0332280',
#  'original_language': 'en',
#  'original_title': 'The Notebook',
#  'overview': "An epic love story centered around an older man who reads aloud to a woman with Alzheimer's. From a faded notebook, the old man's words bring to life the story about a couple who is separated by World War II, and is then passionately reunited, seven years later, after they have taken different paths.",
#  'popularity': 89.271,
#  'poster_path': '/rNzQyW4f8B8cQeg7Dgj3n6eT5k9.jpg',
#  'production_companies': [{'id': 12,
#    'logo_path': '/iaYpEp3LQmb8AfAtmTvpqd4149c.png',
#    'name': 'New Line Cinema',
#    'origin_country': 'US'},
#   {'id': 1565, 'logo_path': None, 'name': 'Avery Pix', 'origin_country': 'US'},
#   {'id': 2605,
#    'logo_path': '/rk0YNJvnHYfRcwRNa7WxxrsJ3xr.png',
#    'name': 'Gran Via Productions',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2004-06-25',
#  'revenue': 115603229,
#  'runtime': 123,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Behind every great love is a great story.',
#  'title': 'The Notebook',
#  'video': False,
#  'vote_average': 7.883,
#  'vote_count': 10749,
#  'certification': 'PG-13'}

# %% [markdown]
# - Confirmed API function is working properly.

# %%
YEAR = 2001
errors = []
file_exists = os.path.isfile(JSON_FILE_2001)
JSON_FILE_2001 = f'{FOLDER}tmdb_api_results_{YEAR}.json'

if file_exists == False:
    print(f'Creating{JSON_FILE_2001} for API results for year = {YEAR}.')
    with open (JSON_FILE_2001, 'w') as f:
        json.dump([{'imdb_id':0}],f)

else:
    print(f'The file {JSON_FILE_2001} already exists.')
# Out:
# The file Data/tmdb_api_results_2001.json already exists.

# %%
#filtering for movies from selected startYear
df2001 = basics.loc[basics['startYear']==YEAR].copy()
movie_ids = df2001['tconst']
movie_ids
# Out:
# 0        tt0035423
# 10       tt0114447
# 14       tt0116916
# 18       tt0118589
# 19       tt0118652
#            ...
# 84623    tt9071078
# 85100    tt9212730
# 85135    tt9228234
# 85957    tt9555974
# 86015    tt9578462
# Name: tconst, Length: 1576, dtype: object

# %%
# Load existing data from json into a dataframe called 'previous_df'
previous_df = pd.read_json(JSON_FILE_2001)
previous_df
# Out:
#       imdb_id  adult                     backdrop_path  \
# 0           0    NaN                               NaN
# 1   tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg
# 2   tt0114447    0.0                              None
# 3   tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4   tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# 5   tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg
# 6   tt0119004    0.0  /r7bxHKEzgrURm9qhEaAayIMG4Xi.jpg
# 7   tt0120166    0.0  /havCE85OV7FUMWzqAZ9x31XRRCA.jpg
# 8   tt0120624    0.0  /gaVOAGPq2LRvwmtUI6dLiBpnql3.jpg
# 9   tt0120681    0.0  /xo2S7gRwCvWdVqM0Swv37yA2rzw.jpg
# 10  tt0120737    0.0  /x2RS3uTcsJJ9IfjNPcgDmukoEcQ.jpg
# 11  tt0120807    0.0                              None
# 12  tt0120824    0.0  /gnyGSoVKOIz1BR34lIBuuTq0Znl.jpg
# 13  tt0123581    0.0                              None
# 14  tt0124889    0.0                              None
# 15  tt0125022    0.0  /ayRhG0eoQwJ6il7bmXGrZx8rUta.jpg
# 16  tt0126029    0.0  /sRvXNDItGlWCqtO3j6wks52FmbD.jpg
# 17  tt0126899    0.0                              None
# 18  tt0128165    0.0                              None
# 19  tt0132078    0.0                              None
# 20  tt0132245    0.0  /w4Jvkb6BQGvQ3K3aECMsy6bZln3.jpg
# 21  tt0133063    0.0                              None
# 22  tt0133152    0.0  /rF0Y0fYVsNFEvGve8Nq0Ij9EDCM.jpg
# 23  tt0139654    0.0  /nuO8o9ltxhI7AZQxePavEZ4TyHa.jpg
# 24  tt0141120    0.0  /nMtgKt70fxrjxiN17VdXAzylanu.jpg
# 25  tt0141907    0.0  /l1VJVGohlSDSQr85hZNlZjMlb6L.jpg
# 26  tt0146316    0.0  /6a3tiuwoM0vyytHkQHNmMppijCe.jpg
# 27  tt0148415    0.0                              None
# 28  tt0150021    0.0  /5O57Up7qcSoi6LgI3uxa0J2BsgC.jpg
#
#                                 belongs_to_collection       budget  \
# 0                                                 NaN          NaN
# 1                                                None   48000000.0
# 2                                                None          0.0
# 3                                                None          0.0
# 4                                                None   22000000.0
# 5                                                None    1000000.0
# 6                                                None          0.0
# 7                                                None          0.0
# 8                                                None          0.0
# 9                                                None   35000000.0
# 10  {'id': 119, 'name': 'The Lord of the Rings Col...   93000000.0
# 11                                               None          0.0
# 12                                               None   38000000.0
# 13                                               None          0.0
# 14                                               None          0.0
# 15                                               None   35000000.0
# 16  {'id': 2150, 'name': 'Shrek Collection', 'post...   60000000.0
# 17                                               None     150000.0
# 18                                               None          0.0
# 19                                               None          0.0
# 20                                               None   94000000.0
# 21                                               None          0.0
# 22                                               None  100000000.0
# 23  {'id': 945477, 'name': 'Training Day Collectio...   45000000.0
# 24                                               None          0.0
# 25                                               None   90000000.0
# 26  {'id': 2467, 'name': 'Tomb Raider Collection',...  115000000.0
# 27                                               None          0.0
# 28                                               None   10000000.0
#
#                                                genres  \
# 0                                                 NaN
# 1   [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...
# 2   [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 3   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 5   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 6                       [{'id': 18, 'name': 'Drama'}]
# 7   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 8   [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 9   [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...
# 10  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 11                                                 []
# 12  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 13                                                 []
# 14                                                 []
# 15  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 16  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 17  [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...
# 18  [{'id': 10749, 'name': 'Romance'}, {'id': 28, ...
# 19                     [{'id': 35, 'name': 'Comedy'}]
# 20  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 21                                                 []
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 23  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 24                     [{'id': 28, 'name': 'Action'}]
# 25  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 26  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 27                    [{'id': 14, 'name': 'Fantasy'}]
# 28  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                              homepage        id  \
# 0                                                 NaN       NaN
# 1                                                       11232.0
# 2                                                      151007.0
# 3                                                       73549.0
# 4                                                       10696.0
# 5                                                       17140.0
# 6                                                       37857.0
# 7                                                       50944.0
# 8                                                       50230.0
# 9                                                         768.0
# 10                     http://www.lordoftherings.net/     120.0
# 11                                                     164074.0
# 12     http://www.miramax.com/movie/the-shipping-news    6440.0
# 13                                                     252682.0
# 14                                                     291638.0
# 15                                                      10833.0
# 16          http://www.dreamworksanimation.com/shrek/     808.0
# 17                                                      30030.0
# 18                                                     293856.0
# 19                       http://www.deadbymonday.com/  248745.0
# 20                                                      10477.0
# 21                                                     528728.0
# 22  http://www.planetoftheapes.com/films/planet-of...     869.0
# 23                                                       2034.0
# 24                                                     112797.0
# 25                                                      24113.0
# 26                                                       1995.0
# 27                                                     417867.0
# 28                                                      56085.0
#
#    original_language                                     original_title  ...  \
# 0                NaN                                                NaN  ...
# 1                 en                                     Kate & Leopold  ...
# 2                 en                                   The Silent Force  ...
# 3                 en                                      The Dark Mist  ...
# 4                 en                                            Glitter  ...
# 5                 en                              The Attic Expeditions  ...
# 6                 en                                         Don's Plum  ...
# 7                 en                          The Sorcerer's Apprentice  ...
# 8                 pt                                           Camarate  ...
# 9                 en                                          From Hell  ...
# 10                en  The Lord of the Rings: The Fellowship of the Ring  ...
# 11                es                                     Ricochet River  ...
# 12                en                                  The Shipping News  ...
# 13                en                             Burning Down the House  ...
# 14                en                                             Sticks  ...
# 15                en                                      Heartbreakers  ...
# 16                en                                              Shrek  ...
# 17                en                                  Eyes Are Upon You  ...
# 18                en                                            Blazin'  ...
# 19                en                                     Dead by Monday  ...
# 20                en                                             Driven  ...
# 21                en                                         Lightmaker  ...
# 22                en                                 Planet of the Apes  ...
# 23                en                                       Training Day  ...
# 24                en                                          The Ghost  ...
# 25                en                                     Town & Country  ...
# 26                en                            Lara Croft: Tomb Raider  ...
# 27                en                             Little Shop of Erotica  ...
# 28                en                                         Camouflage  ...
#
#         revenue  runtime                                   spoken_languages  \
# 0           NaN      NaN                                                NaN
# 1    76019048.0    118.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 2           0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3           0.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     5271666.0    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5           0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 6        6297.0    108.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7           0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 8           0.0    100.0  [{'english_name': 'Portuguese', 'iso_639_1': '...
# 9    74558115.0    122.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 10  871368364.0    179.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 11          0.0    112.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12   24690441.0    111.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 13          0.0     84.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 14          0.0      0.0                                                 []
# 15   57800000.0    123.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 16  487853320.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 17          0.0     92.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 18          0.0      0.0                                                 []
# 19          0.0     94.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 20   54744738.0    116.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 21          0.0     73.0                                                 []
# 22  362211740.0    120.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 23  104900000.0    122.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 24          0.0     86.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 25   10372291.0    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 26  274703340.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 27          0.0     87.0                                                 []
# 28          0.0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#       status                                            tagline  \
# 0        NaN                                                NaN
# 1   Released  If they lived in the same century, they'd be p...
# 2   Released  They left him for dead... They should have fin...
# 3   Released
# 4   Released   In music she found her dream, her love, herself.
# 5   Released  His search for peace of mind... will leave his...
# 6   Released                  Tonight's Special - Group Therapy
# 7   Released
# 8   Released
# 9   Released                      Only the legend will survive.
# 10  Released                          One ring to rule them all
# 11  Released
# 12  Released      You'll never guess what you'll find inside...
# 13  Released
# 14  Released
# 15  Released                    Caution: Dangerous Curves Ahead
# 16  Released                The greatest fairy tale never told.
# 17  Released
# 18  Released
# 19  Released
# 20  Released               Get ready for the race of your life.
# 21  Released
# 22  Released          You'll be sorry you were ever born human.
# 23  Released  The only thing more dangerous than the line be...
# 24  Released
# 25  Released           There's no such thing as a small affair.
# 26  Released  Born into Wealth. Groomed by the Elite. Traine...
# 27  Released
# 28  Released
#
#                                                 title  video  vote_average  \
# 0                                                 NaN    NaN           NaN
# 1                                      Kate & Leopold    0.0         6.325
# 2                                    The Silent Force    0.0         5.000
# 3                                       The Dark Mist    0.0         3.500
# 4                                             Glitter    0.0         4.405
# 5                               The Attic Expeditions    0.0         5.156
# 6                                          Don's Plum    0.0         5.300
# 7                           The Sorcerer's Apprentice    0.0         4.600
# 8                                            Camarate    0.0         7.286
# 9                                           From Hell    0.0         6.686
# 10  The Lord of the Rings: The Fellowship of the Ring    0.0         8.405
# 11                                     Ricochet River    0.0         7.500
# 12                                  The Shipping News    0.0         6.300
# 13                             Burning Down the House    0.0        10.000
# 14                                             Sticks    0.0         0.000
# 15                                      Heartbreakers    0.0         6.071
# 16                                              Shrek    0.0         7.731
# 17                                  Eyes Are Upon You    0.0         1.000
# 18                                            Blazin'    0.0         4.000
# 19                                     Dead by Monday    0.0         6.000
# 20                                             Driven    0.0         5.135
# 21                                         Lightmaker    0.0         0.000
# 22                                 Planet of the Apes    0.0         5.700
# 23                                       Training Day    0.0         7.490
# 24                                          The Ghost    0.0         2.000
# 25                                     Town & Country    0.0         4.492
# 26                            Lara Croft: Tomb Raider    0.0         5.882
# 27                             Little Shop of Erotica    0.0         3.500
# 28                                         Camouflage    0.0         4.209
#
#    vote_count certification
# 0         NaN           NaN
# 1      1243.0         PG-13
# 2         3.0           NaN
# 3         2.0            PG
# 4       132.0         PG-13
# 5        32.0             R
# 6        74.0           NaN
# 7        11.0            NR
# 8         7.0           NaN
# 9      2609.0             R
# 10    23612.0         PG-13
# 11        2.0
# 12      342.0             R
# 13        1.0
# 14        0.0
# 15      833.0         PG-13
# 16    15996.0            PG
# 17        1.0
# 18        1.0
# 19        1.0         PG-13
# 20      654.0         PG-13
# 21        0.0           NaN
# 22     3726.0         PG-13
# 23     5452.0             R
# 24        4.0
# 25       61.0             R
# 26     5746.0         PG-13
# 27        2.0
# 28       55.0             R
#
# [29 rows x 26 columns]

# %%
#filter out any ids that are alrady in the JSON_FILE_2001
movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

# %%
# Loop through movie_ids with a tqdm progress bar
for movie_id in tqdm_notebook(movie_ids_to_get, f'Movies from {YEAR}'):
    try:
        temp= get_movie_with_rating(movie_id)
        write_json(temp,JSON_FILE_2001)
        time.sleep(0.02)

    except Exception as e:
        errors.append([movie_id,e])
# Out:
# Movies from 2001:   0%|          | 0/1548 [00:00<?, ?it/s]

# %%
print(f'-Total errors: {len(errors)}')
# Out:
# -Total errors: 217

# %%
# Save the results to a csv.gz file
final_year_df1 = pd.read_json(JSON_FILE_2001)
csv_fname= f'{FOLDER}final_tmdb_data_{YEAR}.csv.gz'
final_year_df1.to_csv(csv_fname, compression='gzip', index=False)

# %%
final_year_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1360 entries, 0 to 1359
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1360 non-null   object
#  1   adult                  1359 non-null   float64
#  2   backdrop_path          757 non-null    object
#  3   belongs_to_collection  100 non-null    object
#  4   budget                 1359 non-null   float64
#  5   genres                 1359 non-null   object
#  6   homepage               1359 non-null   object
#  7   id                     1359 non-null   float64
#  8   original_language      1359 non-null   object
#  9   original_title         1359 non-null   object
#  10  overview               1359 non-null   object
#  11  popularity             1359 non-null   float64
#  12  poster_path            1232 non-null   object
#  13  production_companies   1359 non-null   object
#  14  production_countries   1359 non-null   object
#  15  release_date           1359 non-null   object
#  16  revenue                1359 non-null   float64
#  17  runtime                1359 non-null   float64
#  18  spoken_languages       1359 non-null   object
#  19  status                 1359 non-null   object
#  20  tagline                1359 non-null   object
#  21  title                  1359 non-null   object
#  22  video                  1359 non-null   float64
#  23  vote_average           1359 non-null   float64
#  24  vote_count             1359 non-null   float64
#  25  certification          878 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 276.4+ KB

# %% [markdown]
# ---

# %%
# Set the year to filter for 
YEAR1 = 2002
# Create an empty list for saving errors
errors =[]

# %%
# Define the JSON file to store results for the year
JSON_FILE_2002 = f'{FOLDER}tmdb_api_results_{YEAR1}.json'
file_exists = os.path.isfile(JSON_FILE_2002)

if file_exists == False:
    print(f'Creating {JSON_FILE_2002} for API results for year={YEAR1}.')
    with open (JSON_FILE_2002, 'w') as f:
        json.dump([{'imdb_id':0}],f)

else:
    print(f'The file {JSON_FILE_2002} already exists.')
# Out:
# Creating Data/tmdb_api_results_2002.json for API results for year=2002.

# %%
# Filtering for movies from selected startYear
df2002=basics.loc[basics['startYear']==YEAR1].copy()
movie_ids_2002 = df2002['tconst']
movie_ids_2002
# Out:
# 4        tt0096056
# 23       tt0118926
# 32       tt0119980
# 44       tt0120679
# 51       tt0120804
#            ...
# 82658    tt8474326
# 83742    tt8825252
# 84317    tt8993336
# 86310    tt9683502
# 86850    tt9874290
# Name: tconst, Length: 1572, dtype: object

# %%
len(movie_ids_2002)
# Out:
# 1572

# %%
# Load existing data from json into a dataframe called 'previous_df2002'
previous_df1 = pd.read_json(JSON_FILE_2002)
previous_df1
# Out:
#    imdb_id
# 0        0

# %%
movie_ids_to_get_2002 = movie_ids_2002[~movie_ids_2002.isin(previous_df1['imdb_id'])]
movie_ids_to_get_2002
# Out:
# 4        tt0096056
# 23       tt0118926
# 32       tt0119980
# 44       tt0120679
# 51       tt0120804
#            ...
# 82658    tt8474326
# 83742    tt8825252
# 84317    tt8993336
# 86310    tt9683502
# 86850    tt9874290
# Name: tconst, Length: 1572, dtype: object

# %%
for movie_id in tqdm_notebook(movie_ids_to_get_2002, f'Movies from {YEAR1}'):
    try:
        temp = get_movie_with_rating(movie_id)
        write_json(temp,JSON_FILE_2002)
        time.sleep(0.02)

    except Exception as e:
        errors.append([movie_id,e])
# Out:
# Movies from 2002:   0%|          | 0/1572 [00:00<?, ?it/s]

# %%
final_year_df2 = pd.read_json(JSON_FILE_2002)

# %%
final_year_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1296 non-null   object
#  1   adult                  1295 non-null   float64
#  2   backdrop_path          786 non-null    object
#  3   belongs_to_collection  122 non-null    object
#  4   budget                 1295 non-null   float64
#  5   genres                 1295 non-null   object
#  6   homepage               1295 non-null   object
#  7   id                     1295 non-null   float64
#  8   original_language      1295 non-null   object
#  9   original_title         1295 non-null   object
#  10  overview               1295 non-null   object
#  11  popularity             1295 non-null   float64
#  12  poster_path            1182 non-null   object
#  13  production_companies   1295 non-null   object
#  14  production_countries   1295 non-null   object
#  15  release_date           1295 non-null   object
#  16  revenue                1295 non-null   float64
#  17  runtime                1295 non-null   float64
#  18  spoken_languages       1295 non-null   object
#  19  status                 1295 non-null   object
#  20  tagline                1295 non-null   object
#  21  title                  1295 non-null   object
#  22  video                  1295 non-null   float64
#  23  vote_average           1295 non-null   float64
#  24  vote_count             1295 non-null   float64
#  25  certification          853 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 263.4+ KB

# %%
csv_fname1 = f'{FOLDER}final_tmdb_data_{YEAR1}.csv.gz'
final_year_df2.to_csv(csv_fname1, compression='gzip', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Combine All API results

# %%
import glob
tmdb_files = sorted(glob.glob('Data/final_tmdb_data*.csv.gz'))
tmdb_files
# Out:
# ['Data/final_tmdb_data_2001.csv.gz', 'Data/final_tmdb_data_2002.csv.gz']

# %%
# Combine with concat to load all files
df=pd.concat([pd.read_csv(f, lineterminator='\n') for f in tmdb_files])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2656 entries, 0 to 1295
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2656 non-null   object
#  1   adult                  2654 non-null   float64
#  2   backdrop_path          1543 non-null   object
#  3   belongs_to_collection  222 non-null    object
#  4   budget                 2654 non-null   float64
#  5   genres                 2654 non-null   object
#  6   homepage               213 non-null    object
#  7   id                     2654 non-null   float64
#  8   original_language      2654 non-null   object
#  9   original_title         2654 non-null   object
#  10  overview               2596 non-null   object
#  11  popularity             2654 non-null   float64
#  12  poster_path            2414 non-null   object
#  13  production_companies   2654 non-null   object
#  14  production_countries   2654 non-null   object
#  15  release_date           2629 non-null   object
#  16  revenue                2654 non-null   float64
#  17  runtime                2654 non-null   float64
#  18  spoken_languages       2654 non-null   object
#  19  status                 2654 non-null   object
#  20  tagline                1156 non-null   object
#  21  title                  2654 non-null   object
#  22  video                  2654 non-null   float64
#  23  vote_average           2654 non-null   float64
#  24  vote_count             2654 non-null   float64
#  25  certification          824 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 560.2+ KB

# %%
#Save final merged csv as 'tmdb_results_combined.csv.gz'
fname = f'{FOLDER}tmdb_results_combined.csv.gz'
df.to_csv(fname, compression='gzip',index=False)
